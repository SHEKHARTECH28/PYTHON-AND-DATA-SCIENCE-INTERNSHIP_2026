# %% [markdown]
# #### 1) Practice print statement: - with multiple object - with seperator - with "ends" 2) Using input ask user to enter his/her name and output user name with a greeting message

# %%
# Multiple objects
print("My", "name", "is", "Shekhar")

# Using separator
print("2026", "05", "20", sep="-")

# Using end
print("Hello", end=" ")
print("World")
# Out:
# My name is Shekhar
# 2026-05-20
# Hello World

# %%
name = input("Enter your name: ")
print("Hello,", name, "! Welcome.")
# Out:
# Hello, Shekhar ! Welcome.

# %% [markdown]
# ###combined code

# %%
# Print statement practice
print("My", "name", "is", "Shekhar")
print("Python", "Programming", sep=" - ")
print("Welcome", end=" ")
print("Students")

# Input and greeting
name = input("\nEnter your name: ")
print("Hello,", name, "! Have a great day.")
# Out:
# My name is Shekhar
# Python - Programming
# Welcome Students
# Hello, Shekhar Saini ! Have a great day.
