# %%
# 1) Study the open weather API show more data in your API calling program

import requests

def weather_data(city):
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=1872bb02e30343d99ae9e210edf3ca4c&units=metric"

    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        print("City:", data["name"])
        print("Humidity:", data["main"]["humidity"])
        print("Temperature:", data["main"]["temp"])
        print("Feels Like:", data["main"]["feels_like"])
        print("Minimum Temperature:", data["main"]["temp_min"])
        print("Maximum Temperature:", data["main"]["temp_max"])

    except requests.exceptions.RequestException as e:
        print("Error:", e)
    except KeyError as e:
        print("Data not found:", e)

city = input("Enter city name: ")
weather_data(city)
# Out:
# City: Niwai
# Humidity: 9
# Temperature: 42.95
# Feels Like: 39.66
# Minimum Temperature: 42.95
# Maximum Temperature: 42.95

# %% [markdown]
# ### 3) Search for more free API's generate your and call them to fetch data. Display some data in your program.

# %%
import requests

def news_data():
    url = "https://newsapi.org/v2/top-headlines?country=us&category=business&apiKey=7b505153182644b2890174f5fb86e976"

    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        print("Top Business News Headlines:\n")

        for article in data["articles"][:5]:

            print("Title:", article["title"])
            print("Author:", article["author"])
            print("Source:", article["source"]["name"])
            print("Published At:", article["publishedAt"])
            print("Description:", article["description"])
            print("-" * 60)

    except requests.exceptions.RequestException as e:
        print("Error:", e)

news_data()
# Out:
# Top Business News Headlines:
#
# Title: We found the best deals at the Amazon Memorial Day sale — Apple, Ninja, Adidas and more are up to 70% off - Yahoo
# Author: Carrie McCabe
# Source: Yahoo Entertainment
# Published At: 2026-05-23T14:20:05Z
# Description: We've spotted some standout price drops on spring style, self-care essentials, summer stock-ups and more.
# ------------------------------------------------------------
# Title: Trump’s 3,711 Trades Point to Multiple Stock-Market Strategies - Bloomberg.com
# Author: Justina Lee, Vivien Ngo, Elena Popina, Matthew Griffin
# Source: Bloomberg
# Published At: 2026-05-23T13:00:16Z
# Description: Index-tracking and automated execution appear to be on show in transactions linked to the president.
# ------------------------------------------------------------
# Title: High fuel prices test limits of summer vacation spending - CNBC
# Author: Leslie Josephs
# Source: CNBC
# Published At: 2026-05-23T12:00:01Z
# ...

# %% [markdown]
# ### 2) Try building today's game yourself

# %%
import random
low=0
high=100
gues=0
random.randint
number=random.randint(low,high)
while True:
    guess=int(input(f"enter a number between({low}-{high}):"))
    gues+=1
    if(guess<number):
        print(f"{guess}is too low")
    elif(guess>number):
        print(f"{guess} is too high")
    else:
        print(f"{guess} is correct")
        break
    print(f"this round takes you{gues} guesss")
# Out:
# 56is too low
# this round takes you1 guesss
# 78is too low
# this round takes you2 guesss
# 98 is too high
# this round takes you3 guesss
# 89is too low
# this round takes you4 guesss
# 93 is correct

# %%
import random
l=["rock ","paper","scissors"]
uscore=0
sccore=0

uch=input("Enter You  CHOICE ")
print(" Your choice is "+ uch)
cch=random.choice(l)
print("computer choice "+ cch)
if((uch=="rock" and cch=="rock") or
   (uch=="scissors"and cch=="scissors") or
   (uch=="paper"and cch=="paper")):
   print("BOTH ARE Done TRY AGAIN")
   uscore=+1
   cscore=+1
elif((uch=="rock" and cch=="scissors") or
     (uch=="paper" and cch=="rock") or
     (uch=="scissors" and cch=="paper")):
     uscore+=2
     print("you win")
else:
    print("COMPUTER WIN")
# Out:
#  Your choice is rock
# computer choice scissors
# you win
